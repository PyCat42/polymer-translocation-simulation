# %%
from src.SimulationAnalysis import plot_time_histos, plot_time_histos_comparisson, plot_time_histos_colapse, plot_times, plot_times_comparison, plot_waiting_time, translocation_success_rate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 from SimulationAnalysis import plot_time_histos, plot_time_histos_comparisson, plot_time_histos_colapse, plot_times, plot_times_comparison, plot_waiting_time, translocation_success_rate
#
# File ~\PycharmProjects\PythonProject4\SimulationAnalysis.py:8
#       6 import numpy as np
#       7 from matplotlib import pyplot as plt, cm
# ----> 8 import seaborn as sns
#      11 def merge_dicts(dict_list):
#      12     """
#      13     Merge all result dictionaries created from multiple simulation runs.
#      14     :param dict_list: list with names of .npy files to which result dictionaries have been saved
#    (...)     20                 value = list of waiting times per monomer
#      21     """
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# create dict lists

FB_escape_dict_list = ["FB_E0_N10_first200samples.npy", "FB_E0_N10_rest800samples.npy","FB_E0_N15_first500samples.npy", "FB_E0_N15_second500samples.npy", "FB_E0_N20_first500samples.npy", "FB_E0_N30_first100samples.npy", "FB_E0_N40_first100samples.npy"]

FB_translocation_dict_list = ["FB_E5_N10_first1000samples.npy", "FB_E5_N15_first1000samples.npy", "FB_E5_N20_first1000samples.npy", "FB_E5_N30_first100samples.npy", "FB_E5_N40_first50samples.npy", "FB_E5_N40_second50samples.npy"]

LD_escape_dict_list = ["LD_E0_N10_first1000examples.npy", "LD_E0_N15_first1000examples.npy", "LD_E0_N20_first500examples.npy", "LD_E0_N30_first100examples.npy", "LD_E0_N40_first100examples.npy"]

LD_translocation_dict_list = ["LD_E5_N10_first1000examples.npy", "LD_E5_N15_first1000examples.npy", "LD_E5_N20_first1000examples.npy", "LD_E5_N30_first100examples.npy", "LD_E5_N40_first100examples.npy"]

# %%
plot_time_histos("FB", "escape", FB_escape_dict_list, normalize=False, do_pdf=False)

# %%
plot_time_histos("FB", "translocation", FB_translocation_dict_list, normalize=False, do_pdf=False)

# %%
plot_time_histos("LD", "escape", LD_escape_dict_list, normalize=False, do_pdf=False)

# %%
plot_time_histos("LD", "translocation", LD_translocation_dict_list, normalize=False, do_pdf=False)

# %%
plot_time_histos_comparisson("escape", FB_escape_dict_list, LD_escape_dict_list)

# %%
plot_time_histos_comparisson("translocation", FB_translocation_dict_list, LD_translocation_dict_list)

# %%
plot_time_histos_colapse("FB", "escape", FB_escape_dict_list)

# %%
plot_time_histos_colapse("FB", "translocation", FB_translocation_dict_list)

# %%
plot_time_histos_colapse("LD", "escape", LD_escape_dict_list)

# %%
plot_time_histos_colapse("LD", "translocation", LD_translocation_dict_list)

# %%
plot_times("FB", "escape",  FB_escape_dict_list)
plot_times("FB", "translocation",  FB_translocation_dict_list)

# %%
plot_times("LD", "escape",  LD_escape_dict_list)
plot_times("LD", "translocation",  LD_translocation_dict_list)

# %%
plot_times_comparison("escape", FB_escape_dict_list, LD_escape_dict_list)
plot_times_comparison("translocation", FB_translocation_dict_list, LD_translocation_dict_list)

# %%
plot_waiting_time("FB", FB_translocation_dict_list)

# %%
plot_waiting_time("LD", LD_translocation_dict_list)

# %%
translocation_success_rate("FB", FB_translocation_dict_list)
# Out:
# N = 10: Total Runs = 1000, Successes = 428, Rate = 42.80%
# N = 15: Total Runs = 1000, Successes = 432, Rate = 43.20%
# N = 20: Total Runs = 1000, Successes = 391, Rate = 39.10%
# N = 30: Total Runs = 100, Successes = 37, Rate = 37.00%
# N = 40: Total Runs = 100, Successes = 47, Rate = 47.00%

# %%
translocation_success_rate("LD", LD_translocation_dict_list)
# Out:
# N = 10: Total Runs = 1000, Successes = 937, Rate = 93.70%
# N = 15: Total Runs = 1000, Successes = 929, Rate = 92.90%
# N = 20: Total Runs = 1000, Successes = 922, Rate = 92.20%
# N = 30: Total Runs = 100, Successes = 95, Rate = 95.00%
# N = 40: Total Runs = 100, Successes = 93, Rate = 93.00%
